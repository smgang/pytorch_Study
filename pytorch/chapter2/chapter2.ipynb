# %% [markdown]
# # Convolutional Neural Network
# - CIFAR-10 dataset

# %% [markdown]
# ## 1. Settings
# ### 1) Import required libraries

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable

# %% [markdown]
# ### 2) Set hyperparameters

# %%
batch_size = 256
learning_rate = 0.0002
num_epoch = 20

# %% [markdown]
# ## 2. Data Generation
#
# ### 1) Download Data

# %%
mnist_train = dset.CIFAR10("./", train=True, transform=transforms.ToTensor(), target_transform=None, download=True)
mnist_test = dset.CIFAR10("./", train=False, transform=transforms.ToTensor(), target_transform=None, download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./
# Files already downloaded and verified

# %% [markdown]
# ### 2) Check Dataset

# %%
print(mnist_train.__getitem__(0)[0].size(), mnist_train.__len__())
mnist_test.__getitem__(0)[0].size(), mnist_test.__len__()
# Out:
# torch.Size([3, 32, 32]) 50000
# (torch.Size([3, 32, 32]), 10000)

# %% [markdown]
# ### 3) Set DataLoader

# %%
train_loader = torch.utils.data.DataLoader(mnist_train,batch_size=batch_size, shuffle=True,num_workers=2,drop_last=True)
test_loader = torch.utils.data.DataLoader(mnist_test,batch_size=batch_size, shuffle=False,num_workers=2,drop_last=True)


for X, y in test_loader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", y.shape, y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([256, 3, 32, 32])
# Shape of y:  torch.Size([256]) torch.int64

# %% [markdown]
# ## 3. Model & Optimizer
#
# ### 1) CNN Model

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.layer = nn.Sequential(
            nn.Conv2d(3,16,3,padding=1),
            nn.ReLU(),
            nn.Conv2d(16,32,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2), # 32 x 16 x 16
            
            nn.Conv2d(32,64,3,padding=1),
            nn.ReLU(),
            nn.Conv2d(64,128,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2), # 128 x 8 x 8
            
            nn.Conv2d(128,256,3,padding=1),
            nn.ReLU(),
            nn.Conv2d(256,256,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
        )
        self.flatten = nn.Flatten()
        self.fc_layer = nn.Sequential(
            nn.Linear(256*4*4,256),
            nn.ReLU(),
            nn.Linear(256,10)
        )       
        
    def forward(self,x):
        out = self.layer(x)
        out = self.flatten(out)
        out = self.fc_layer(out)

        return out

model = CNN().cuda()
print(model)
# Out:
# CNN(
#   (layer): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc_layer): Sequential(
#     (0): Linear(in_features=4096, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
from torchsummary import summary
summary(model, (3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#               ReLU-2           [-1, 16, 32, 32]               0
#             Conv2d-3           [-1, 32, 32, 32]           4,640
#               ReLU-4           [-1, 32, 32, 32]               0
#          MaxPool2d-5           [-1, 32, 16, 16]               0
#             Conv2d-6           [-1, 64, 16, 16]          18,496
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8          [-1, 128, 16, 16]          73,856
#               ReLU-9          [-1, 128, 16, 16]               0
#         MaxPool2d-10            [-1, 128, 8, 8]               0
#            Conv2d-11            [-1, 256, 8, 8]         295,168
#              ReLU-12            [-1, 256, 8, 8]               0
#            Conv2d-13            [-1, 256, 8, 8]         590,080
#              ReLU-14            [-1, 256, 8, 8]               0
#         MaxPool2d-15            [-1, 256, 4, 4]               0
#           Flatten-16                 [-1, 4096]               0
#            Linear-17                  [-1, 256]       1,048,832
#              ReLU-18                  [-1, 256]               0
#            Linear-19                   [-1, 10]           2,570
# ================================================================
# Total params: 2,034,090
# Trainable params: 2,034,090
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.19
# Params size (MB): 7.76
# Estimated Total Size (MB): 9.96
# ----------------------------------------------------------------

# %%
param_list = list(model.children())
print(param_list)
# Out:
# [Sequential(
#   (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU()
#   (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU()
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU()
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU()
#   (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ), Flatten(start_dim=1, end_dim=-1), Sequential(
#   (0): Linear(in_features=4096, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=10, bias=True)
# )]

# %% [markdown]
# ### 2) Loss func & Optimizer

# %%
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### 3) Load Model

# %%
try:
    model = torch.load('./cifar_model.pkl')
    print("model restored")
except:
    print("model not restored")
# Out:
# model not restored

# %% [markdown]
# ## 4. Train

# %%
for i in range(num_epoch):
    for j,[image,label] in enumerate(train_loader):
        x = Variable(image).cuda()
        y_= Variable(label).cuda()
        
        optimizer.zero_grad()
        output = model.forward(x)
        loss = loss_func(output,y_)
        loss.backward()
        optimizer.step()
        
        if j % 100 == 0:
            print(loss.data,i,j)
            torch.save(model,'./cifar_model.pkl')
# Out:
# tensor(2.3057, device='cuda:0') 0 0
# tensor(1.8745, device='cuda:0') 0 100
# tensor(1.6487, device='cuda:0') 1 0
# tensor(1.4580, device='cuda:0') 1 100
# tensor(1.5945, device='cuda:0') 2 0
# tensor(1.4300, device='cuda:0') 2 100
# tensor(1.3382, device='cuda:0') 3 0
# tensor(1.2967, device='cuda:0') 3 100
# tensor(1.3799, device='cuda:0') 4 0
# tensor(1.3582, device='cuda:0') 4 100
# tensor(1.3015, device='cuda:0') 5 0
# tensor(1.3221, device='cuda:0') 5 100
# tensor(1.0847, device='cuda:0') 6 0
# tensor(1.2162, device='cuda:0') 6 100
# tensor(1.0911, device='cuda:0') 7 0
# tensor(1.1460, device='cuda:0') 7 100
# tensor(1.1096, device='cuda:0') 8 0
# tensor(1.0449, device='cuda:0') 8 100
# tensor(0.9094, device='cuda:0') 9 0
# tensor(1.0133, device='cuda:0') 9 100
# tensor(0.7803, device='cuda:0') 10 0
# tensor(0.9301, device='cuda:0') 10 100
# tensor(0.9624, device='cuda:0') 11 0
# tensor(0.9005, device='cuda:0') 11 100
# tensor(0.8650, device='cuda:0') 12 0
# tensor(0.8133, device='cuda:0') 12 100
# tensor(0.8191, device='cuda:0') 13 0
# tensor(0.8257, device='cuda:0') 13 100
# tensor(0.7732, device='cuda:0') 14 0
# tensor(0.8270, device='cuda:0') 14 100
# tensor(0.8414, device='cuda:0') 15 0
# tensor(0.7794, device='cuda:0') 15 100
# tensor(0.6931, device='cuda:0') 16 0
# tensor(0.7226, device='cuda:0') 16 100
# tensor(0.6614, device='cuda:0') 17 0
# tensor(0.6685, device='cuda:0') 17 100
# tensor(0.7882, device='cuda:0') 18 0
# tensor(0.8013, device='cuda:0') 18 100
# tensor(0.5443, device='cuda:0') 19 0
# tensor(0.5842, device='cuda:0') 19 100

# %% [markdown]
# ## 5. Test

# %%
correct = 0
total = 0

for image,label in test_loader:
    x = Variable(image,volatile=True).cuda()
    y_= Variable(label).cuda()

    output = model.forward(x)
    _,output_index = torch.max(output,1)
        
    total += label.size(0)
    correct += (output_index == y_).sum().float()
    
print("Accuracy of Test Data: {}".format(100*correct/total))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   """
# Accuracy of Test Data: 71.00360870361328
